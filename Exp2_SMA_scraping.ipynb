# %% [markdown]
# **Part 1- Scraping Youtube Video Comments**

# %% [markdown]
# **Use** **API_key**

# %%
import requests

# %%
video_id = "R3GfuzLMPkA"

# %%
api_key = "AIzaSyBrINsyS8g5121cG6SqCwKf8bc_DPlUm3E"

# %% [markdown]
# **Retrieve video** **information**

# %%
# Retrieve video information
video_info_url = f"https://www.googleapis.com/youtube/v3/videos?part=snippet&id={video_id}&key={api_key}"
video_info_response = requests.get(video_info_url)
video_info_data = video_info_response.json()

# %%
video_info_data
# Out:
# {'kind': 'youtube#videoListResponse',
#  'etag': 'Xs3fTLDsAqE6I1WHzcJD4GJwTSQ',
#  'items': [{'kind': 'youtube#video',
#    'etag': 'bJEq7-IpXKNg6UQGO8M-mOa-G5k',
#    'id': 'R3GfuzLMPkA',
#    'snippet': {'publishedAt': '2016-12-23T02:29:02Z',
#     'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'title': '4K ULtra HD | SAMSUNG UHD Demo׃ LED TV',
#     'description': 'Short 4K Ultra High Definition demonstration by Samsung.',
#     'thumbnails': {'default': {'url': 'https://i.ytimg.com/vi/R3GfuzLMPkA/default.jpg',
#       'width': 120,
#       'height': 90},
#      'medium': {'url': 'https://i.ytimg.com/vi/R3GfuzLMPkA/mqdefault.jpg',
#       'width': 320,
#       'height': 180},
#      'high': {'url': 'https://i.ytimg.com/vi/R3GfuzLMPkA/hqdefault.jpg',
#       'width': 480,
#       'height': 360},
#      'standard': {'url': 'https://i.ytimg.com/vi/R3GfuzLMPkA/sddefault.jpg',
#       'width': 640,
#       'height': 480},
#      'maxres': {'url': 'https://i.ytimg.com/vi/R3GfuzLMPkA/maxresdefault.jpg',
#       'width': 1280,
#       'height': 720}},
#     'channelTitle': '4K Ultra HD',
#     'tags': ['4K Video Test',
#      '4K videos',
#      '4K Video Ultra HD',
#      '4K Gaming',
#      '4k Music Video',
#      '4K Demo',
#      '4k Movie',
#      '4k Test',
#      '4K Monitor',
#      '4K TV',
#      'UHD 4K Video',
#      'UHD Video',
#      'UHD Movies',
#      'UHD Demo',
#      'UHD 4K',
#      'UHD Blu ray',
#      'UHD vs SUHD',
#      'UHD vs 4K',
#      'UHD TV',
#      'UHD 4K Demo',
#      'SUHD TV Samsung',
#      'SUHD vs OLED',
#      'SUHD vs UHD',
#      'SUHD Demo',
#      'SUHD Tv vs OLED',
#      'SUHD TV Gaming',
#      'SUHD TV Prank',
#      'SUHD LG',
#      'SUHD TV Commercial',
#      '22160p 60fps',
#      '2160p 4K Videos',
#      '2160 Pixel Video',
#      '2160p 4K Movies'],
#     'categoryId': '28',
#     'liveBroadcastContent': 'none',
#     'localized': {'title': '4K ULtra HD | SAMSUNG UHD Demo׃ LED TV',
#      'description': 'Short 4K Ultra High Definition demonstration by Samsung.'}}}],
#  'pageInfo': {'totalResults': 1, 'resultsPerPage': 1}}

# %% [markdown]
# **Retrieve video comment**s

# %%
# Retrieve video compnts
comments_url = f"https://www.googleapis.com/youtube/v3/commentThreads?part=snippet&videoId={video_id}&key={api_key}"
comments_response= requests.get(comments_url)
comments_data = comments_response.json()

# %%
comments_data
# Out:
# {'kind': 'youtube#commentThreadListResponse',
#  'etag': 'VXj_VzKv-t9I9EdnYJOKrR8YXi8',
#  'nextPageToken': 'Z2V0X25ld2VzdF9maXJzdC0tQ2dnSWdBUVZGN2ZST0JJRkNJa2dHQUFTQlFpSElCZ0FFZ1VJcUNBWUFCSUZDSWdnR0FBU0JRaWRJQmdCR0FBaURnb01DSUhGeGRRRkVPaThoTmNC',
#  'pageInfo': {'totalResults': 20, 'resultsPerPage': 20},
#  'items': [{'kind': 'youtube#commentThread',
#    'etag': 'HR5mUDhAimclGT4rpNxeCf49JGs',
#    'id': 'UgwYTbr2lkcIAmzVvjN4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'eWjowSV2lC8Fmcft80dKg5dI0pw',
#      'id': 'UgwYTbr2lkcIAmzVvjN4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Wow..',
#       'textOriginal': 'Wow..',
#       'authorDisplayName': '@akbar_poki87',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/d6Qnk-bsyXP1I0ipxvaL8DSdEW87MkncwVvlyuA8UTPdkEbBsU9LbXEJYzWeuIc2nJZeugUhDg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@akbar_poki87',
#       'authorChannelId': {'value': 'UC7pycqF6UEy34xfyskMBJ5w'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-12-13T12:41:51Z',
#       'updatedAt': '2020-12-13T12:41:51Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'EZB5AL7on2LtnPOhWAlJ8l34syk',
#    'id': 'Ugzenv3EQXP1tNnp13h4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'dZ65z44M0pDBtnk0Lt_u2nLQ674',
#      'id': 'Ugzenv3EQXP1tNnp13h4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Who&#39;s watching on M30s?',
#       'textOriginal': "Who's watching on M30s?",
#       'authorDisplayName': '@mcsdigital5223',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/99WZMPnDu0GyYSLfUl3GaLqntDcrAAk_nR7wKtWaRwAl3Ac6eT2eZ1tI8eL8IBAbfQAJ6qo5pg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@mcsdigital5223',
#       'authorChannelId': {'value': 'UCHw-SQYw9MDnP2X3gwMmuZA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2020-07-28T23:52:59Z',
#       'updatedAt': '2020-07-28T23:52:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'OK-UyvPGFEU2OrruEKNCufyPzqk',
#    'id': 'Ugx2DbsCsNhR39Na8RV4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MkNzPs2OAujHBgV6hgLwsyWJRD0',
#      'id': 'Ugx2DbsCsNhR39Na8RV4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Wow the demonstration they tried is superb. Clearly would promote those 4K TVs. 8~10K footages are available too i believe :) Can&#39;t wait to see TVs that are even clearer than my naked eye!! <br>(We have some of these too !! hahaha)<br>Nice video anyways !! (thumbs up!!! X 100)',
#       'textOriginal': "Wow the demonstration they tried is superb. Clearly would promote those 4K TVs. 8~10K footages are available too i believe :) Can't wait to see TVs that are even clearer than my naked eye!! \n(We have some of these too !! hahaha)\nNice video anyways !! (thumbs up!!! X 100)",
#       'authorDisplayName': '@keycutstock1660',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro
'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2019-09-07T22:48:56Z',
#       'updatedAt': '2019-09-07T22:48:56Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'TckUemTbOJT3NNXRnsxEH-TQo0s',
#    'id': 'Ugy5Jvw4WRyc43N0GVR4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'Jp-Pt1NrcUVPrBzeroNnoDyso1o',
#      'id': 'Ugy5Jvw4WRyc43N0GVR4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'I am waiting for upcoming next higher resolution !!',
#       'textOriginal': 'I am waiting for upcoming next higher resolution !!',
#       'authorDisplayName': '@abhishekkamal4627',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nvC273k-QKgNH2ujRaaW4BPKUQATYw9Odb6PBwzBhfYoQ=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@abhishekkamal4627',
#       'authorChannelId': {'value': 'UCHsb_StXZNcYS2C90bVFtpA'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2019-07-01T15:31:19Z',
#       'updatedAt': '2019-07-01T15:31:19Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'GusDXj6hu1D8wWAIl3xQg3CTtO4',
#    'id': 'UgyWaYfPsUer7-Ed9t94AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'z2WHuMKOMoXZQfrIk4BcubP5KpY',
#      'id': 'UgyWaYfPsUer7-Ed9t94AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Nice',
#       'textOriginal': 'Nice',
#       'authorDisplayName': '@johnnyaingel5753',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/pQT8R0FrV5PadscEQBWuLF9K30eO1Hp1B1drXJyksud-2jb_80D2JO_GCwp77xHc4lpRKE3xnkg=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@johnnyaingel5753',
#       'authorChannelId': {'value': 'UC4u_luTOd2Cb6BRXxT8hebg'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2018-06-18T02:25:59Z',
#       'updatedAt': '2018-06-18T02:25:59Z'}},
#     'canReply': True,
#     'totalReplyCount': 1,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'DbPKhI7awVTtZS1b1HwN2Xo2MY8',
#    'id': 'UgzURufxb6ZzGjyagRt4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'K4pRmyJL06dLv6FVjBZBSpmQiIg',
#      'id': 'UgzURufxb6ZzGjyagRt4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': '144p=:c WORST QUALITY IN THE WORLD !!!!<br>240p=:\\ no<br>360p=:| oof<br>480p=:P meh<br>720p=:) not bad<br>1080P=c: i like it<br>1440p= :DDD i like it much<br>2160p=:DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD I love it<br>8k Love love love<br>32k love love love love love <br>64k Like in real life',
#       'textOriginal': '144p=:c WORST QUALITY IN THE WORLD !!!!\n240p=:\\ no\n360p=:| oof\n480p=:P meh\n720p=:) not bad\n1080P=c: i like it\n1440p= :DDD i like it much\n2160p=:DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD
z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'F87YvY2cxCMGJQNBBrUw5iAOshk',
#    'id': 'UgjtRs6CTsQQ5HgCoAEC',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MxL0poYzo2KoH0OQn6KHA_9WdTE',
#      'id': 'UgjtRs6CTsQQ5HgCoAEC',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Nice...............',
#       'textOriginal': 'Nice...............',
#       'authorDisplayName': '@praveenkumar-cr7eu',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_mjsZnzHkKRh4kDKawa4H4Raa_v8yU81sRaGDEgq0CLKA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@praveenkumar-cr7eu',
#       'authorChannelId': {'value': 'UC2GB0n2FYvGfPcLDw0lZKpQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 1,
#       'publishedAt': '2018-03-28T12:15:35Z',
#       'updatedAt': '2018-03-28T12:15:35Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'r6iGQkZGZic9qGatK7_6-bAMkXo',
#    'id': 'Ugz6gZP9XFdawYW2_at4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'MYb_3HNEiSrukrcjnoJz6SZpSFg',
#      'id': 'Ugz6gZP9XFdawYW2_at4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'جميل',
#       'textOriginal': 'جميل',
#       'authorDisplayName': '@user-or4zh7su5u',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_nBSBhSeNZlovhhMCu_fn8IpL0h7COgXtZa0nGpbUsAYKn3=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@user-or4zh7su5u',
#       'authorChannelId': {'value': 'UCdrHg2JpeH8yGR5D_p_LIgQ'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2018-03-23T20:30:39Z',
#       'updatedAt': '2018-03-23T20:30:39Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'F9AyQf95qRVRHDiiCRtINq18EjU',
#    'id': 'UgyIrZghTBUUK76VV7d4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'okDxb5I8dJU7_3lYUfolouZInjg',
#      'id': 'UgyIrZghTBUUK76VV7d4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'This wasn&#39;t good at all. I just watched it on a new 28&quot; Samsung 4K Display and it was kind of blurry. Then I watched some Sony 4k and GoPro 4k demo&#39;s and they were brilliant beyond words.',
#       'textOriginal': 'This wasn\'t good at all. I just watched it on a new 28" Samsung 4K Display and it was kind of blurry. Then I watched some Sony 4k and GoPro 4k demo\'s and they were brilliant beyond words.',
#       'authorDisplayName': '@oB_Session',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/w9SsNASVJXf_DsJMfyiU1N3EalS-MviwKHEaVmxUTc0qsRgSpGDm-vkZW_Guc0JAifrlHQzmCA=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@oB_Session',
#       'authorChannelId': {'value': 'UC2bstIA-spGTT-fs4f-jG0A'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2018-03-06T01:23:20Z',
#       'updatedAt': '2018-03-06T01:23:20Z'}},
#     'canReply': True,
#     'totalReplyCount': 2,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': 'gMupfuEEb2rf0ngP8eFCDsvVbXY',
#    'id': 'Ugy_mQXmIA-59ZlOtCt4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'V2hQB2hpD5c5MyZiOpVEX3k8td8',
#      'id': 'Ugy_mQXmIA-59ZlOtCt4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'Looks amazing on a Galaxy S8+',
#       'textOriginal': 'Looks amazing on a Galaxy S8+',
#       'authorDisplayName': '@randynorley1406',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_m2afbxC-4c_qhCULUEQXbjSxFibu2f5GkLmvgV4IaX28SF=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@randynorley1406',
#       'authorChannelId': {'value': 'UCtNmt5ilSv9tZUN8nbm7xYw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 3,
#       'publishedAt': '2018-03-03T01:56:45Z',
#       'updatedAt': '2018-03-03T01:56:45Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}},
#   {'kind': 'youtube#commentThread',
#    'etag': '_8gf9zqbp7CwjpQIzoy2_71kCaE',
#    'id': 'UgyL8cP-sgVl4gxfzsZ4AaABAg',
#    'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#     'videoId': 'R3GfuzLMPkA',
#     'topLevelComment': {'kind': 'youtube#comment',
#      'etag': 'S9qDyI6FqMd-FnO5BxoMs88BrgY',
#      'id': 'UgyL8cP-sgVl4gxfzsZ4AaABAg',
#      'snippet': {'channelId': 'UCDd4_w5djWtZApryeMV4Qjw',
#       'videoId': 'R3GfuzLMPkA',
#       'textDisplay': 'MI Tv 🔥🔥',
#       'textOriginal': 'MI Tv 🔥🔥',
#       'authorDisplayName': '@RRTVTAMIL',
#       'authorProfileImageUrl': 'https://yt3.ggpht.com/ytc/AIdro_lrc_wy5GA2jYcWVWJNAsZNsycVSl1hLSpSujaQm-7ufXo=s48-c-k-c0x00ffffff-no-rj',
#       'authorChannelUrl': 'http://www.youtube.com/@RRTVTAMIL',
#       'authorChannelId': {'value': 'UCxxIVmb9O5OxCwmeExUfuAw'},
#       'canRate': True,
#       'viewerRating': 'none',
#       'likeCount': 0,
#       'publishedAt': '2018-02-24T13:02:57Z',
#       'updatedAt': '2018-02-24T13:02:57Z'}},
#     'canReply': True,
#     'totalReplyCount': 0,
#     'isPublic': True}}]}

# %% [markdown]
# **Extract the comments**

# %%
# Extract the comments
comments = [item["snippet"]["topLevelComment"]["snippet"]["textOriginal"] for item in comments_data["items"]]

# %%
print(comments)
# Out:
# ['Wow..', "Who's watching on M30s?", "Wow the demonstration they tried is superb. Clearly would promote those 4K TVs. 8~10K footages are available too i believe :) Can't wait to see TVs that are even clearer than my naked eye!! \n(We have some of these too !! hahaha)\nNice video anyways !! (thumbs up!!! X 100)", 'Congratulations. I liked this small video.  How can I download this 4K video ?', "I'm seeing this in an LG Hahaha", 'A love me encanta', 'I am waiting for upcoming next higher resolution !!', 'Nice', '144p=:c WORST QUALITY IN THE WORLD !!!!\n240p=:\\ no\n360p=:| oof\n480p=:P meh\n720p=:) not bad\n1080P=c: i like it\n1440p= :DDD i like it much\n2160p=:DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD I love it\n8k Love love love\n32k love love love love love \n64k Like in real life', "Lg make oled tv's", 'ఎంత రేటు', '8k movie ke vaba download kor bo', 'jajaja this look so great in 4k jajajaja', 'WOW, Spectacular!!!', 'Its nice video', 'Nice...............', 'جميل', 'This wasn\'t good at all. I just watched it on a new 28" Samsung 4K Display and it was kind of blurry. Then I watched some Sony 4k and GoPro 4k demo\'s and they were brilliant beyond words.', 'Looks amazing on a Galaxy S8+', 'MI Tv 🔥🔥']

# %%
import pandas as pd

# %%
display = pd.DataFrame({"Comments": comments})

# %%
display.head()
# Out:
#                                             Comments
# 0                                              Wow..
# 1                            Who's watching on M30s?
# 2  Wow the demonstration they tried is superb. Cl...
# 3  Congratulations. I liked this small video.  Ho...
# 4                    I'm seeing this in an LG Hahaha

# %% [markdown]
# **Save Comments to CSV File**

# %%
display.to_csv("YouTube_Comments_Sentiment.csv")

# %% [markdown]
# **Sentiments Analysis of Youtube Comments**

# %%
from textblob import TextBlob

# %%
def get_comment_sentiment(comment):
  analysis = TextBlob(comment)
  if analysis.sentiment.polarity > 0:
    return "Positive"
  elif analysis.sentiment.polarity == 0:
    return "neutral"
  else:
    return "negative"

# %% [markdown]
# **Display the sentiment of Youtube video comments**

# %%
comment_list = []
sentiment_list = []
for comment in comments:
  sentiment = get_comment_sentiment(comment)
  comment_list.append(comment)
  sentiment_list.append(sentiment)
  print(f"{comment} : {sentiment}")
# Out:
# Wow.. : Positive
# Who's watching on M30s? : neutral
# Wow the demonstration they tried is superb. Clearly would promote those 4K TVs. 8~10K footages are available too i believe :) Can't wait to see TVs that are even clearer than my naked eye!!
# (We have some of these too !! hahaha)
# Nice video anyways !! (thumbs up!!! X 100) : Positive
# Congratulations. I liked this small video.  How can I download this 4K video ? : Positive
# I'm seeing this in an LG Hahaha : Positive
# A love me encanta : Positive
# I am waiting for upcoming next higher resolution !! : Positive
# Nice : Positive
# 144p=:c WORST QUALITY IN THE WORLD !!!!
# 240p=:\ no
# 360p=:| oof
# 480p=:P meh
# 720p=:) not bad
# 1080P=c: i like it
# 1440p= :DDD i like it much
# 2160p=:DDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDDD I love it
# 8k Love love love
# 32k love love love love love
# 64k Like in real life : Positive
# Lg make oled tv's : neutral
# ఎంత రేటు : neutral
# 8k movie ke vaba download kor bo : neutral
# jajaja this look so great in 4k jajajaja : Positive
# WOW, Spectacular!!! : Positive
# Its nice video : Positive
# Nice............... : Positive
# جميل : neutral
# This wasn't good at all. I just watched it on a new 28" Samsung 4K Display and it was kind of blurry. Then I watched some Sony 4k and GoPro 4k demo's and they were brilliant beyond words. : Positive
# Looks amazing on a Galaxy S8+ : Positive
# MI Tv 🔥🔥 : neutral

# %%
import pandas as pd

# %%
sentiment_df = pd.DataFrame({"Comments": comment_list,"Sentiment": sentiment_list})

# %%
sentiment_df.head()
# Out:
#                                             Comments Sentiment
# 0                                              Wow..  Positive
# 1                            Who's watching on M30s?   neutral
# 2  Wow the demonstration they tried is superb. Cl...  Positive
# 3  Congratulations. I liked this small video.  Ho...  Positive
# 4                    I'm seeing this in an LG Hahaha  Positive

# %% [markdown]
# **Save Comments to CSV File**

# %%
sentiment_df.to_csv("YouTube_Comments_Sentiment.csv")
